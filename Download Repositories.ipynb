# %%
import os
import json
import glob
import shutil
import requests
import subprocess
import pandas as pd

# %%
def flatten_json(data, output, prefix=""):    
    for key, value in data.items():
        if isinstance(value, dict):
            flatten_json(value, output, key)
        else:
            if(prefix):
                output["{}_{}".format(prefix, key)] = value
            else:
                output[key] = value
    
    return output

# %%
def change_permissions(direc):
    for root, dirs, files in os.walk(direc):
        for f in files:
            os.chmod(os.path.join(root, f), 0o777)
        for d in dirs:
            os.chmod(os.path.join(root, d), 0o777)

# %%
def download_repositories(repository_list, github_token, file_extensions):
    api_endpoint = "https://api.github.com/repos"
    auth_token = "Bearer {}".format(github_token)
    api_headers = {"Authorization": auth_token, "Accept": "application/vnd.github.mercy-preview+json"}
    
    for index, row in pd.read_csv(repository_list).iterrows():
        repo_url = row["repo_url"]
        filename = row["filename"]
        repo_name = repo_url.split("https://github.com/")[-1]
        
        # Ensure repository has not already been downloaded
        if(not os.path.exists(filename)):    
            
            try: 
                # Make request to Github API to get repository metadata
                api_request = requests.get("{}/{}".format(api_endpoint, repo_name), headers=api_headers)

                # Check to make sure API request was successful
                if(api_request.status_code == 200):
                    flatten_request = flatten_json(api_request.json(), {})
                    request_df = pd.DataFrame([flatten_request])

                    # Clone the repo into a new directory named after the arxiv ID of the paper associated with the repo
                    subprocess.call(["git", "clone", repo_url, filename])

                    files = []
                    direcs = []

                    # Change permissions of all files/folders to read/write
                    change_permissions(filename)

                    # Delete .git folder
                    shutil.rmtree("{}/.git".format(filename))

                    # Remove non-code files and empty directories
                    for root, direc, files in os.walk(filename):
                        for f in files:
                            if(f.split(".")[-1] not in file_extensions):
                                os.remove(os.path.join(root, f))
                                
                    for root, direc, files in os.walk(filename):
                        for d in direc:
                            if(not os.listdir(os.path.join(root, d))):
                                os.rmdir(os.path.join(root, d))

                    # Delete repository if empty (this is because the repo has no code)
                    if(not os.listdir(filename)):
                        shutil.rmtree(filename)
                    else:
                        request_df.to_csv("{}/{}.csv".format(filename, filename), encoding="utf-8", index=False)
                        print("Successfully downloaded {}".format(filename))      

                else:
                    # This error occurs if the repo no longer exists or you have reached the API request limit
                    print("Could not download {} due to a network error".format(filename, api_request.status_code))
                    
            except Exception as e:
                print("Could not download {} because {}".format(filename, str(e)))
        
        else:
            print("Repository {} already downloaded".format(filename))

# %%
file_extensions = json.load(open("file_extensions.json", "r"))
languages = set()

for key, value in file_extensions.items():
    for file in value:
        languages.add(file)

download_repositories("dataset.csv", "", languages)
# Out:
# Successfully downloaded 1806.06098v1
# Successfully downloaded 1712.05889v2
# Successfully downloaded 1904.02399v4
# Successfully downloaded 1806.05507v1
# Successfully downloaded 1905.02925v1
# Successfully downloaded 1801.09319v2
# Successfully downloaded 1806.02988v1
# Successfully downloaded 1705.03854v3
# Successfully downloaded 1206.2944v2
# Successfully downloaded 1807.05118v1
# Successfully downloaded 1806.01175v1
# Repository 1206.2944v2 already downloaded
# Successfully downloaded 1805.12048v1
# Successfully downloaded 1803.01299v2
# Successfully downloaded 1805.10799v1
# Successfully downloaded 1711.11511v5
# Successfully downloaded 1711.04956v5
# Successfully downloaded 1903.11114v2
# Successfully downloaded 1604.07316v1
# Successfully downloaded 1708.02551v1
# Successfully downloaded 1805.07499v1
# Successfully downloaded 1611.01603v6
# Successfully downloaded 1402.0929v3
# Successfully downloaded 1805.05480v2
# Successfully downloaded 1805.09843v1
# Successfully downloaded 1805.06504v1
# Successfully downloaded 1403.5607v1
# Successfully downloaded 1903.05942v4
# Successfully downloaded 1805.01577v1
# Successfully downloaded 1805.03359v2
# Successfully downloaded 1809.08835v2
# Successfully downloaded 1805.01209v1
# Successfully downloaded 1703.06891v3
# Successfully downloaded 1704.06767v3
# Successfully downloaded 1811.12326v1
# Successfully downloaded 1904.12324v1
# Successfully downloaded 1804.07187v2
# Successfully downloaded 1806.01413v1
# Successfully downloaded 1804.09557v2
# Successfully downloaded 1711.10485v1
# Successfully downloaded 1804.07629v1
# Successfully downloaded 1909.11646v2
# Successfully downloaded 1610.09950v2
# Successfully downloaded 1811.00854v1
# Successfully downloaded 1706.02582v1
# Successfully downloaded 1804.05834v1
# Successfully downloaded 1712.09005v1
# Successfully downloaded 1812.00442v1
# Successfully downloaded 1804.03396v2
# Successfully downloaded 1707.07998v3
# Successfully downloaded 1706.05206v2
# Successfully downloaded 1606.01541v4
# Successfully downloaded 1504.00736v1
# Successfully downloaded 1803.07136v1
# Successfully downloaded 1811.04860v1
# Successfully downloaded 1809.06846v4
# Successfully downloaded 1902.09212v1
# Successfully downloaded 1806.00437v1
# Successfully downloaded 1507.04808v3
# Successfully downloaded 1804.09699v4
# Successfully downloaded 1312.5602v1
# Successfully downloaded 1803.03816v2
# Successfully downloaded 1709.09590v2
# Successfully downloaded 1803.05796v2
# Successfully downloaded 1710.03748v3
# Successfully downloaded 1802.08526v2
# Successfully downloaded 1901.07884v4
# Successfully downloaded 1706.06689v1
# Successfully downloaded 1504.06375v2
# Successfully downloaded 1505.04597v1
# Successfully downloaded 1802.10353v1
# Successfully downloaded 1606.03802v9
# Successfully downloaded 1802.08979v2
# Successfully downloaded 1706.05208v4
# Successfully downloaded 1607.04606v2
# Repository 1707.07998v3 already downloaded
# Successfully downloaded 1609.04938v2
# Successfully downloaded 1604.02878v1
# Successfully downloaded 1606.07792v1
# Successfully downloaded 1806.05997v1
# Successfully downloaded 1611.09414v2
# Successfully downloaded 1806.05645v1
# Repository 1507.04808v3 already downloaded
# Successfully downloaded 1511.06062v2
# Successfully downloaded 1810.12429v1
# Successfully downloaded 1711.00727v2
# Successfully downloaded 1805.08193v2
# Successfully downloaded 1802.06138v2
# Successfully downloaded 1710.06635v2
# Successfully downloaded 1705.07205v2
# Successfully downloaded 1906.08237v1
# Successfully downloaded 1711.04817v2
# Successfully downloaded 1702.05464v1
# Successfully downloaded 1804.07834v2
# Successfully downloaded 1804.10028v3
# Successfully downloaded 1704.01212v2
# Successfully downloaded 1712.03451v5
# Successfully downloaded 1711.09271v3
# Successfully downloaded 1805.09501v3
# Successfully downloaded 1402.4102v2
# Successfully downloaded 1612.00593v2
# Successfully downloaded 1712.05319v2
# Successfully downloaded 1703.05051v5
# Successfully downloaded 1506.01497v3
# Successfully downloaded 1708.02002v2
# Successfully downloaded 1712.04575v2
# Successfully downloaded 1308.4214v1
# Successfully downloaded 1712.09444v2
# Successfully downloaded 1612.08242v1
# Successfully downloaded 1609.05158v2
# Successfully downloaded 1711.10162v2
# Successfully downloaded 1711.05186v2
# Successfully downloaded 1712.02294v4
# Successfully downloaded 1711.01804v2
# Successfully downloaded 1705.07443v2
# Successfully downloaded 1703.04529v4
# Successfully downloaded 1503.03832v3
# Successfully downloaded 1904.07773v3
# Successfully downloaded 1711.04436v1
# Successfully downloaded 1803.08533v1
# Successfully downloaded 1711.08231v3
# Successfully downloaded 1710.06632v1
# Successfully downloaded 1709.01688v3
# Successfully downloaded 1710.08144v1
# Successfully downloaded 1710.03474v1
# Successfully downloaded 1806.00608v2
# Successfully downloaded 1703.06870v3
# Successfully downloaded 1710.07480v1
# Successfully downloaded 1710.03029v1
# Repository 1609.05158v2 already downloaded
# Successfully downloaded 1705.00581v2
# Successfully downloaded 1709.03202v1
# Successfully downloaded 1709.01189v1
# Successfully downloaded 1708.06185v1
# Successfully downloaded 1807.00311v1
# Successfully downloaded 1606.03498v1
# Successfully downloaded 1804.06657v1
# Successfully downloaded 1708.03392v1
# Successfully downloaded 1706.04148v5
# Successfully downloaded 1708.05768v1
# Repository 1802.08526v2 already downloaded
# Successfully downloaded 1702.00758v4
# Successfully downloaded 1708.00584v1
# Successfully downloaded 1707.03904v2
# Successfully downloaded 1707.07165v1
# Successfully downloaded 1708.01938v1
# Successfully downloaded 1707.05821v1
# Successfully downloaded 1707.05956v1
# Successfully downloaded 1705.05065v2
# Successfully downloaded 1809.05679v3
# Successfully downloaded 1706.03757v2
# Successfully downloaded 1707.05587v1
# Successfully downloaded 1701.06643v1
# Successfully downloaded 1702.06674v2
# Successfully downloaded 1707.04314v1
# Successfully downloaded 1704.03165v3
# Successfully downloaded 1811.09242v1
# Successfully downloaded 1810.01875v1
# Successfully downloaded 1704.04683v5
# Successfully downloaded 1706.02496v1
# Successfully downloaded 1708.00524v2
# Successfully downloaded 1702.05931v2
# Successfully downloaded 1707.08879v1
# Successfully downloaded 1705.07104v2
# Successfully downloaded 1611.08215v2
# Successfully downloaded 1705.10557v1
# Successfully downloaded 1808.09132v2
# Successfully downloaded 1610.06940v3
# Successfully downloaded 1704.07576v1
# Successfully downloaded 1603.05027v3
# Successfully downloaded 1705.00609v1
# Successfully downloaded 1703.03352v1
# Successfully downloaded 1505.02065v6
# Successfully downloaded 1612.06950v2
# Successfully downloaded 1704.05420v2
# Successfully downloaded 1805.12323v1
# Successfully downloaded 1703.01086v3
# Successfully downloaded 1502.01852v1
# Successfully downloaded 1606.09066v3
# Successfully downloaded 1702.05796v1
# Successfully downloaded 1707.06347v2
# Successfully downloaded 1608.05745v4
# Repository 1604.07316v1 already downloaded
# Successfully downloaded 1701.08466v1
# Successfully downloaded 1802.03494v4
# Successfully downloaded 1801.01563v3
# Successfully downloaded 1507.05717v1
# Successfully downloaded 1504.08083v2
# Successfully downloaded 1608.04363v2
# Successfully downloaded 1701.01565v1
# Successfully downloaded 1612.08936v1
# Successfully downloaded 1712.09520v2
# Successfully downloaded 1610.08694v3
# Successfully downloaded 1712.01815v1
# Successfully downloaded 1604.01980v2
# Successfully downloaded 1604.08610v2
# Successfully downloaded 1609.07568v1
# Successfully downloaded 1709.06053v1
# Successfully downloaded 1609.09154v1
# Successfully downloaded 1801.07746v2
# Successfully downloaded 1605.07869v2
# Successfully downloaded 1607.07057v3
# Successfully downloaded 1608.04051v1
# Successfully downloaded 1509.06585v3
# Successfully downloaded 1604.08859v2
# Successfully downloaded 1507.05699v5
# Successfully downloaded 1803.08450v2
# Successfully downloaded 1510.06423v4
# Successfully downloaded 1810.12348v3
# Successfully downloaded 1511.00060v3
# Successfully downloaded 1511.02821v2
# Successfully downloaded 1603.08482v1
# Successfully downloaded 1809.03599v1
# Successfully downloaded 1508.07630v3
# Successfully downloaded 1511.02889v1
# Successfully downloaded 1812.10786v1
# Successfully downloaded 1506.03140v2
# Successfully downloaded 1502.02536v3
# Successfully downloaded 1811.12030v1
# Successfully downloaded 1511.00054v1
# Successfully downloaded 1505.06292v1
# Successfully downloaded 1810.12576v1
# Successfully downloaded 1802.05668v1
# Successfully downloaded 1808.00897v1
# Successfully downloaded 1506.05198v3
# Successfully downloaded 1412.7753v2
# Successfully downloaded 1502.00750v1
# Successfully downloaded 1502.00130v1
# Successfully downloaded 1502.02761v1
# Successfully downloaded 1503.02424v2
# Successfully downloaded 1712.05690v2
# Successfully downloaded 1705.02801v4
# Successfully downloaded 1408.5093v1
# Successfully downloaded 1401.6169v2
# Successfully downloaded 1503.03578v1
# Successfully downloaded 1307.5302v3
# Successfully downloaded 1404.4893v1
# Repository 1712.01815v1 already downloaded
# Successfully downloaded 1705.02364v5
# Successfully downloaded 1811.08988v3
# Successfully downloaded 1703.06345v1
# Successfully downloaded 1711.11575v2
# Successfully downloaded 1905.13391v2
# Successfully downloaded 1803.08375v2
# Repository 1703.06870v3 already downloaded
# Successfully downloaded 1811.09621v2
# Successfully downloaded 1508.07909v5
# Successfully downloaded 1506.03163v4
# Successfully downloaded 1606.01286v2
# Successfully downloaded 1803.11175v2
# Successfully downloaded 1701.02870v3
# Successfully downloaded 1510.00149v5
# Successfully downloaded 1804.07745v3
# Successfully downloaded 1412.6568v3
# Successfully downloaded 1805.06087v1
# Successfully downloaded 1607.00133v2
# Successfully downloaded 1506.02626v3
# Successfully downloaded 1806.07190v2
# Successfully downloaded 1710.04087v3
# Successfully downloaded 1711.05225v3
# Successfully downloaded 1901.05816v1
# Successfully downloaded 1301.3781v3
# Successfully downloaded 1704.00051v2
# Successfully downloaded 1509.02971v6
# Repository 1509.02971v6 already downloaded
# Repository 1312.5602v1 already downloaded
# Successfully downloaded 1612.03242v2
# Successfully downloaded 1412.6651v8
# Successfully downloaded 1612.07119v1
# Successfully downloaded 1605.00316v1
# Successfully downloaded 1412.6980v9
# Successfully downloaded 1511.00561v3
# Successfully downloaded 1703.10960v3
# Successfully downloaded 1608.06993v5
# Successfully downloaded 1704.00794v2
# Successfully downloaded 1706.02216v4
# Successfully downloaded 1512.03385v1
# Successfully downloaded 1508.06576v2
# Successfully downloaded 1808.09031v1
# Successfully downloaded 1605.07146v4
# Successfully downloaded 1709.04348v2
# Repository 1605.07146v4 already downloaded
# Successfully downloaded 1804.07573v4
# Repository 1703.10960v3 already downloaded
# Successfully downloaded 1710.06169v4
# Successfully downloaded 1712.06527v1
# Repository 1512.03385v1 already downloaded
# Successfully downloaded 1607.08221v1
# Repository 1708.02002v2 already downloaded
# Successfully downloaded 1603.07396v1
# Successfully downloaded 1701.02096v2
# Successfully downloaded 1606.07659v3
# Successfully downloaded 1605.06325v1
# Successfully downloaded 1902.09104v1
# Successfully downloaded 1505.00641v3
# Successfully downloaded 1511.06434v2
# Successfully downloaded 1806.06923v1
# Successfully downloaded 1703.08840v2
# Repository 1605.07146v4 already downloaded
# Successfully downloaded 1810.06801v4
# Successfully downloaded 1312.6229v4
# Successfully downloaded 1701.07396v1
# Successfully downloaded 1509.01631v1
# Successfully downloaded 1412.7091v3
# Successfully downloaded 1701.07395v1
# Successfully downloaded 1312.6114v10
# Successfully downloaded 1602.03686v2
# Successfully downloaded 1802.00168v3
# Successfully downloaded 1705.10513v2
# Successfully downloaded 1705.09759v1
# Successfully downloaded 1412.3756v3
# Successfully downloaded 1108.2865v1
# Successfully downloaded 1412.1820v2
# Successfully downloaded 1810.04509v1
# Successfully downloaded 1312.3005v3
# Successfully downloaded 1609.02686v2
# Successfully downloaded 1808.04355v1
# Repository 1708.02002v2 already downloaded
# Successfully downloaded 1709.09686v2
# Successfully downloaded 1704.05143v2
# Successfully downloaded 1702.03274v2
# Successfully downloaded 1406.2661v1
# Successfully downloaded 1902.01560v2
# Successfully downloaded 1804.03999v3
# Successfully downloaded 1409.3215v3
# Successfully downloaded 1612.01010v2
# Successfully downloaded 1910.06711v2
# Successfully downloaded 1706.05125v1
# Successfully downloaded 1804.02744v3
# Successfully downloaded 1702.05373v2
# Successfully downloaded 1706.09262v2
# Successfully downloaded 1706.02332v3
# Successfully downloaded 1507.00448v2
# Successfully downloaded 1806.08565v1
# Successfully downloaded 1711.07240v4
# Successfully downloaded 1809.11100v1
# Successfully downloaded 1602.07776v4
# Successfully downloaded 1803.07043v6
# Successfully downloaded 1606.00253v1
# Successfully downloaded 1609.06647v1
# Successfully downloaded 1705.10843v3
# Successfully downloaded 1509.01692v4
# Successfully downloaded 1611.09326v3
# Successfully downloaded 1502.00873v1
# Successfully downloaded 1409.0473v7
# Repository 1512.03385v1 already downloaded
# Successfully downloaded 1606.07035v3
# Successfully downloaded 1808.00508v1
# Repository 1508.06576v2 already downloaded
# Successfully downloaded 1612.05005v5
# Successfully downloaded 1803.05215v4
# Successfully downloaded 1610.00970v6
# Successfully downloaded 1810.04805v2
# Successfully downloaded 1709.01860v1
# Successfully downloaded 1711.05769v2
# Successfully downloaded 1706.02515v5
# Successfully downloaded 1703.07469v1
# Successfully downloaded 1712.00726v1
# Successfully downloaded 1712.02478v1
# Successfully downloaded 1605.07723v3
# Successfully downloaded 1804.08450v1
# Successfully downloaded 1708.02286v2
# Successfully downloaded 1905.00877v6
# Successfully downloaded 1706.01789v2
# Successfully downloaded 1706.01427v1
# Successfully downloaded 1503.03167v4
# Successfully downloaded 1704.00028v3
# Successfully downloaded 1612.00563v2
# Successfully downloaded 1611.02167v3
# Successfully downloaded 1803.10082v1
# Repository 1604.07316v1 already downloaded
# Successfully downloaded 1909.00453v1
# Successfully downloaded 1606.02147v1
# Successfully downloaded 1412.7062v4
# Successfully downloaded 1611.01884v3
# Successfully downloaded 1708.00077v1
# Successfully downloaded 1705.07962v2
# Successfully downloaded 1905.01067v3
# Successfully downloaded 1811.09393v2
# Successfully downloaded 1811.00403v2
# Successfully downloaded 1704.02447v2
# Successfully downloaded 1906.11455v2
# Successfully downloaded 1611.06455v4
# Successfully downloaded 1602.02644v2
# Repository 1708.02002v2 already downloaded
# Successfully downloaded 1903.10728v1
# Successfully downloaded 1612.04402v2
# Repository 1604.02878v1 already downloaded
# Successfully downloaded 1606.04809v3
# Successfully downloaded 1606.09375v3
# Repository 1510.00149v5 already downloaded
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1504.06603v2
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1805.08318v2
# Successfully downloaded 1905.06873v1
# Successfully downloaded 1611.06310v2
# Successfully downloaded 1608.08128v3
# Successfully downloaded 1707.08866v1
# Successfully downloaded 1905.05559v1
# Successfully downloaded 1710.10916v3
# Successfully downloaded 1610.04794v2
# Successfully downloaded 1612.03144v2
# Successfully downloaded 1711.03705v1
# Successfully downloaded 1605.06409v2
# Successfully downloaded 1807.07281v3
# Successfully downloaded 1810.08130v2
# Successfully downloaded 1706.05781v1
# Successfully downloaded 1602.02697v4
# Successfully downloaded 1806.04965v2
# Successfully downloaded 1803.07116v2
# Successfully downloaded 1607.06349v1
# Successfully downloaded 1812.08350v2
# Successfully downloaded 1611.02174v1
# Successfully downloaded 1906.00133v1
# Successfully downloaded 1705.02304v1
# Successfully downloaded 1704.02161v2
# Successfully downloaded 1711.04043v3
# Successfully downloaded 1411.4038v2
# Successfully downloaded 1802.04942v5
# Repository 1406.2661v1 already downloaded
# Successfully downloaded 1806.07498v1
# Successfully downloaded 1806.07186v1
# Successfully downloaded 1612.02903v1
# Successfully downloaded 1806.01664v2
# Successfully downloaded 1707.06682v1
# Successfully downloaded 1702.08502v3
# Successfully downloaded 1802.03426v2
# Repository 1507.05717v1 already downloaded
# Successfully downloaded 1603.06147v4
# Successfully downloaded 1611.07004v3
# Repository 1703.06870v3 already downloaded
# Successfully downloaded 1806.08195v1
# Successfully downloaded 1806.03653v1
# Successfully downloaded 1605.08833v1
# Successfully downloaded 1802.10311v2
# Successfully downloaded 1506.08909v3
# Successfully downloaded 1902.08727v1
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1503.08895v5
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1411.0292v2
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1312.4400v3
# Successfully downloaded 1701.06547v5
# Successfully downloaded 1705.08841v1
# Repository 1707.06347v2 already downloaded
# Successfully downloaded 1804.06208v2
# Successfully downloaded 1502.03240v3
# Successfully downloaded 1812.01483v2
# Successfully downloaded 1606.04316v3
# Successfully downloaded 1801.06126v3
# Successfully downloaded 1702.00288v3
# Successfully downloaded 1502.05477v5
# Successfully downloaded 1810.08427v1
# Successfully downloaded 1902.11004v1
# Successfully downloaded 1901.07031v1
# Successfully downloaded 1702.08835v3
# Successfully downloaded 1511.06410v3
# Successfully downloaded 1806.09907v1
# Successfully downloaded 1901.03353v1
# Successfully downloaded 1703.03906v2
# Successfully downloaded 1711.06396v1
# Successfully downloaded 1906.06059v2
# Repository 1312.5602v1 already downloaded
# Successfully downloaded 1704.06125v1
# Successfully downloaded 1408.5882v2
# Successfully downloaded 1803.07192v1
# Successfully downloaded 1811.08760v2
# Successfully downloaded 1809.10168v1
# Repository 1810.04805v2 already downloaded
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1709.00382v2
# Repository 1605.06409v2 already downloaded
# Successfully downloaded 1709.00138v1
# Successfully downloaded 1811.10597v2
# Successfully downloaded 1703.06211v3
# Successfully downloaded 1708.05997v2
# Repository 1705.02304v1 already downloaded
# Successfully downloaded 1806.11298v2
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1803.09974v2
# Repository 1704.06125v1 already downloaded
# Successfully downloaded 1505.07818v4
# Successfully downloaded 1607.04673v4
# Repository 1611.07004v3 already downloaded
# Successfully downloaded 1506.03134v2
# Successfully downloaded 1907.03261v1
# Successfully downloaded 1902.00311v1
# Repository 1408.5882v2 already downloaded
# Successfully downloaded 1610.09083v1
# Successfully downloaded 1807.01197v2
# Successfully downloaded 1409.0107v1
# Successfully downloaded 1206.5278v1
# Successfully downloaded 1803.03396v2
# Repository 1506.08909v3 already downloaded
# Successfully downloaded 1612.03651v1
# Successfully downloaded 1702.08726v1
# Successfully downloaded 1403.6652v2
# Successfully downloaded 1506.05163v1
# Successfully downloaded 1312.6203v3
# Successfully downloaded 1807.01774v1
# Repository 1606.09375v3 already downloaded
# Successfully downloaded 1707.07113v4
# Successfully downloaded 1802.05591v1
# Successfully downloaded 1601.01272v2
# Successfully downloaded 1612.09346v3
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1609.04802v5
# Successfully downloaded 1512.05193v4
# Repository 1712.01815v1 already downloaded
# Successfully downloaded 1905.02716v1
# Repository 1612.03242v2 already downloaded
# Successfully downloaded 1711.11585v2
# Successfully downloaded 1805.03779v3
# Repository 1611.07004v3 already downloaded
# Successfully downloaded 1605.05396v2
# Successfully downloaded 1605.05395v1
# Repository 1708.02002v2 already downloaded
# Successfully downloaded 1703.10593v6
# Repository 1603.05027v3 already downloaded
# Repository 1503.03832v3 already downloaded
# Successfully downloaded 1711.08324v1
# Successfully downloaded 1708.02182v1
# Successfully downloaded 1507.02672v2
# Successfully downloaded 1805.08028v2
# Successfully downloaded 1608.05347v1
# Successfully downloaded 1904.12796v3
# Successfully downloaded 1907.05653v1
# Successfully downloaded 1701.05369v3
# Successfully downloaded 1610.07717v3
# Successfully downloaded 1712.09093v3
# Successfully downloaded 1703.07737v4
# Successfully downloaded 1707.02038v2
# Successfully downloaded 1807.02684v3
# Successfully downloaded 1506.03694v2
# Successfully downloaded 1901.07213v4
# Successfully downloaded 1411.4555v2
# Successfully downloaded 1802.05046v2
# Successfully downloaded 1903.00179v2
# Successfully downloaded 1509.06461v3
# Successfully downloaded 1603.09727v1
# Successfully downloaded 1505.00393v3
# Successfully downloaded 1610.01271v4
# Successfully downloaded 1904.07387v2
# Successfully downloaded 1703.08710v2
# Successfully downloaded 1806.06850v3
# Successfully downloaded 1503.08169v2
# Repository 1504.08083v2 already downloaded
# Successfully downloaded 1807.00028v2
# Successfully downloaded 1406.2572v1
# Successfully downloaded 1511.02680v2
# Successfully downloaded 1703.02914v1
# Successfully downloaded 1904.07936v4
# Repository 1804.08450v1 already downloaded
# Successfully downloaded 1805.03064v3
# Successfully downloaded 1703.03864v2
# Successfully downloaded 1710.10768v1
# Successfully downloaded 1712.04086v3
# Successfully downloaded 1603.01417v1
# Successfully downloaded 1709.03831v1
# Successfully downloaded 1703.10131v2
# Repository 1511.00561v3 already downloaded
# Successfully downloaded 1905.10291v3
# Successfully downloaded 1904.11005v1
# Successfully downloaded 1706.03762v5
# Successfully downloaded 1707.02725v2
# Successfully downloaded 1405.4053v2
# Successfully downloaded 1909.03745v2
# Successfully downloaded 1802.05944v2
# Successfully downloaded 1807.07860v2
# Successfully downloaded 1702.02138v2
# Successfully downloaded 1806.02825v1
# Successfully downloaded 1807.00399v3
# Successfully downloaded 1708.05509v1
# Successfully downloaded 1602.01783v2
# Successfully downloaded 1904.01310v1
# Successfully downloaded 1805.09927v1
# Successfully downloaded 1708.02711v1
# Successfully downloaded 1202.2194v4
# Successfully downloaded 1806.10741v1
# Successfully downloaded 1707.05612v4
# Successfully downloaded 1711.06178v1
# Repository 1604.07316v1 already downloaded
# Repository 1412.6980v9 already downloaded
# Successfully downloaded 1603.08511v5
# Repository 1708.02182v1 already downloaded
# Successfully downloaded 1804.08771v2
# Repository 1509.02971v6 already downloaded
# Successfully downloaded 1806.04326v3
# Successfully downloaded 1703.03130v1
# Successfully downloaded 1704.04861v1
# Successfully downloaded 1711.05851v2
# Successfully downloaded 1805.09190v3
# Successfully downloaded 1702.01824v2
# Repository 1703.06211v3 already downloaded
# Successfully downloaded 1505.06389v3
# Successfully downloaded 1706.04284v3
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1711.09670v1
# Successfully downloaded 1812.01187v2
# Repository 1409.0473v7 already downloaded
# Repository 1509.02971v6 already downloaded
# Repository 1508.06576v2 already downloaded
# Successfully downloaded 1603.08155v1
# Successfully downloaded 1605.09782v7
# Successfully downloaded 1812.01504v4
# Successfully downloaded 1410.2838v1
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1612.00901v1
# Successfully downloaded 1902.02595v3
# Successfully downloaded 1802.07687v2
# Successfully downloaded 1805.07526v2
# Successfully downloaded 1707.07012v4
# Successfully downloaded 1704.07911v1
# Successfully downloaded 1903.08778v2
# Repository 1612.03144v2 already downloaded
# Successfully downloaded 1602.07125v2
# Successfully downloaded 1706.10295v3
# Successfully downloaded 1810.03947v4
# Successfully downloaded 1803.10404v3
# Successfully downloaded 1806.06371v2
# Successfully downloaded 1906.00452v1
# Repository 1509.02971v6 already downloaded
# Successfully downloaded 1711.03190v3
# Successfully downloaded 1506.02025v3
# Could not download 1902.09314v2 due to a network error
# Successfully downloaded 1711.11561v1
# Successfully downloaded 1701.07875v3
# Successfully downloaded 1506.05869v3
# Successfully downloaded 1606.02393v5
# Repository 1706.02515v5 already downloaded
# Successfully downloaded 1806.01579v1
# Successfully downloaded 1409.1556v6
# Successfully downloaded 1712.09913v3
# Repository 1512.03385v1 already downloaded
# Successfully downloaded 1802.04208v3
# Successfully downloaded 1807.03039v2
# Successfully downloaded 1903.01620v2
# Successfully downloaded 1610.09585v4
# Successfully downloaded 1506.06256v1
# Successfully downloaded 1002.3174v3
# Successfully downloaded 1407.4075v1
# Repository 1605.05396v2 already downloaded
# Successfully downloaded 1808.03578v2
# Successfully downloaded 1701.08140v3
# Repository 1511.06434v2 already downloaded
# Successfully downloaded 1803.09719v3
# Successfully downloaded 1808.03351v1
# Successfully downloaded 1911.04554v1
# Successfully downloaded 1711.09020v3
# Successfully downloaded 1810.00123v2
# Successfully downloaded 1611.09405v1
# Successfully downloaded 1812.01965v1
# Successfully downloaded 1806.09835v1
# Successfully downloaded 1804.11271v2
# Successfully downloaded 1907.13337v1
# Successfully downloaded 1808.04487v1
# Successfully downloaded 1808.06876v3
# Successfully downloaded 1804.00823v4
# Successfully downloaded 1606.00298v1
# Successfully downloaded 1806.01946v3
# Successfully downloaded 1901.09590v2
# Repository 1703.03130v1 already downloaded
# Successfully downloaded 1412.6575v4
# Successfully downloaded 1611.07932v2
# Successfully downloaded 1802.02950v4
# Successfully downloaded 1902.10903v1
# Successfully downloaded 1807.06906v1
# Successfully downloaded 1705.09307v1
# Repository 1707.06347v2 already downloaded
# Successfully downloaded 1511.06581v3
# Repository 1611.07004v3 already downloaded
# Successfully downloaded 1702.03814v3
# Successfully downloaded 1811.07417v1
# Successfully downloaded 1809.02847v2
# Successfully downloaded 1809.02701v4
# Successfully downloaded 1611.05425v1
# Successfully downloaded 1606.00094v2
# Successfully downloaded 1603.01360v3
# Successfully downloaded 1806.06259v1
# Successfully downloaded 1411.5799v2
# Successfully downloaded 1703.00395v1
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1703.10155v2
# Successfully downloaded 1711.08585v4
# Successfully downloaded 1906.00358v2
# Successfully downloaded 1803.10459v4
# Successfully downloaded 1808.07962v1
# Successfully downloaded 1808.08931v2
# Successfully downloaded 1904.09664v2
# Repository 1505.07818v4 already downloaded
# Successfully downloaded 1808.08933v2
# Successfully downloaded 1608.00859v1
# Successfully downloaded 1811.01424v1
# Successfully downloaded 1710.10044v1
# Repository 1602.01783v2 already downloaded
# Successfully downloaded 1808.09044v1
# Repository 1612.03144v2 already downloaded
# Repository 1708.02002v2 already downloaded
# Repository 1705.05065v2 already downloaded
# Repository 1502.05477v5 already downloaded
# Successfully downloaded 1808.09945v1
# Successfully downloaded 1702.08359v2
# Repository 1608.06993v5 already downloaded
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1806.08730v1
# Successfully downloaded 1508.01991v1
# Successfully downloaded 1606.03476v1
# Repository 1511.06434v2 already downloaded
# Successfully downloaded 1802.06205v1
# Successfully downloaded 1704.04224v1
# Successfully downloaded 1707.05414v5
# Successfully downloaded 1703.02628v3
# Successfully downloaded 1506.02640v5
# Successfully downloaded 1610.02357v3
# Successfully downloaded 1608.03981v1
# Repository 1503.08895v5 already downloaded
# Successfully downloaded 1802.02422v2
# Successfully downloaded 1905.03389v1
# Successfully downloaded 1808.09814v1
# Successfully downloaded 1710.10903v3
# Successfully downloaded 1806.09231v2
# Successfully downloaded 1709.00503v2
# Successfully downloaded 1707.07930v1
# Successfully downloaded 1906.00297v1
# Successfully downloaded 1810.05281v1
# Successfully downloaded 1803.02758v4
# Successfully downloaded 1602.07360v4
# Repository 1511.06434v2 already downloaded
# Successfully downloaded 1712.06087v1
# Successfully downloaded 1805.10407v4
# Successfully downloaded 1605.06211v1
# Successfully downloaded 1803.08823v3
# Repository 1708.02002v2 already downloaded
# Successfully downloaded 1703.03949v2
# Successfully downloaded 1611.01734v3
# Successfully downloaded 1607.04423v4
# Successfully downloaded 1611.01462v3
# Successfully downloaded 1902.04478v1
# Successfully downloaded 1801.06146v5
# Successfully downloaded 1806.09045v4
# Successfully downloaded 1809.03132v1
# Successfully downloaded 1706.03779v2
# Successfully downloaded 1702.04869v1
# Successfully downloaded 1809.04137v1
# Repository 1712.09005v1 already downloaded
# Successfully downloaded 1809.04212v2
# Successfully downloaded 1705.02798v6
# Successfully downloaded 1810.02245v1
# Successfully downloaded 1806.00557v2
# Successfully downloaded 1602.07043v2
# Repository 1703.10593v6 already downloaded
# Successfully downloaded 1308.0850v5
# Repository 1802.04208v3 already downloaded
# Successfully downloaded 1703.00810v3
# Successfully downloaded 1811.07062v2
# Successfully downloaded 1809.05042v1
# Successfully downloaded 1803.10342v2
# Successfully downloaded 1809.05884v2
# Successfully downloaded 1802.10229v2
# Repository 1603.05027v3 already downloaded
# Successfully downloaded 1810.09361v2
# Repository 1710.10903v3 already downloaded
# Successfully downloaded 1611.09119v2
# Successfully downloaded 1711.07264v2
# Successfully downloaded 1802.03685v4
# Successfully downloaded 1608.04644v2
# Successfully downloaded 1706.05692v3
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1609.04468v3
# Repository 1511.06434v2 already downloaded
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1812.02900v3
# Successfully downloaded 1807.05317v1
# Successfully downloaded 1512.00567v3
# Successfully downloaded 1606.00915v2
# Successfully downloaded 1708.06433v2
# Successfully downloaded 1804.07918v2
# Successfully downloaded 1705.03550v1
# Successfully downloaded 1603.06937v2
# Successfully downloaded 1609.04309v3
# Repository 1409.3215v3 already downloaded
# Repository 1706.02515v5 already downloaded
# Successfully downloaded 1712.07695v1
# Successfully downloaded 1603.03417v1
# Successfully downloaded 1703.07015v3
# Successfully downloaded 1809.08771v1
# Successfully downloaded 1704.08509v1
# Successfully downloaded 1802.07934v2
# Successfully downloaded 1806.05490v3
# Repository 1508.06576v2 already downloaded
# Successfully downloaded 1809.08390v1
# Successfully downloaded 1809.02627v1
# Repository 1612.00593v2 already downloaded
# Successfully downloaded 1904.07619v2
# Successfully downloaded 1809.10200v1
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1711.10604v1
# Successfully downloaded 1704.02463v2
# Successfully downloaded 1708.06670v3
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1807.10454v3
# Repository 1711.04043v3 already downloaded
# Successfully downloaded 1711.09151v1
# Successfully downloaded 1810.02840v2
# Successfully downloaded 1605.03170v3
# Successfully downloaded 1706.08564v1
# Successfully downloaded 1904.07734v1
# Successfully downloaded 1804.03641v2
# Successfully downloaded 1810.00694v1
# Successfully downloaded 1805.08462v2
# Repository 1611.07004v3 already downloaded
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1712.00600v1
# Successfully downloaded 1904.07741v1
# Repository 1611.07004v3 already downloaded
# Successfully downloaded 1805.00930v2
# Successfully downloaded 1810.01222v3
# Successfully downloaded 1511.06349v4
# Successfully downloaded 1805.04051v3
# Could not download 1810.02244v2 due to a network error
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1807.09644v3
# Successfully downloaded 1712.06567v3
# Successfully downloaded 1811.12231v2
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1708.00107v2
# Successfully downloaded 1706.09528v1
# Successfully downloaded 1810.01860v1
# Repository 1512.00567v3 already downloaded
# Successfully downloaded 1804.02668v1
# Successfully downloaded 1702.03859v1
# Successfully downloaded 1706.04599v2
# Successfully downloaded 1702.02170v1
# Successfully downloaded 1903.05179v1
# Successfully downloaded 1802.07535v3
# Repository 1805.00930v2 already downloaded
# Successfully downloaded 1805.08587v5
# Successfully downloaded 1812.01729v2
# Successfully downloaded 1709.07492v2
# Could not download 1612.01895v2 due to a network error
# Successfully downloaded 1404.1777v2
# Successfully downloaded 1804.04522v4
# Successfully downloaded 1911.08666v1
# Repository 1611.01603v6 already downloaded
# Repository 1707.05612v4 already downloaded
# Successfully downloaded 1911.08827v1
# Successfully downloaded 1803.02155v2
# Successfully downloaded 1606.01933v2
# Successfully downloaded 1810.06339v1
# Successfully downloaded 1801.06378v1
# Successfully downloaded 1705.07283v2
# Repository 1301.3781v3 already downloaded
# Successfully downloaded 1603.09056v2
# Successfully downloaded 1703.05175v2
# Successfully downloaded 1810.07167v1
# Successfully downloaded 1704.01085v3
# Successfully downloaded 1606.00373v2
# Successfully downloaded 1904.05049v3
# Repository 1611.02174v1 already downloaded
# Repository 1708.02002v2 already downloaded
# Repository 1512.03385v1 already downloaded
# Successfully downloaded 1709.06919v2
# Successfully downloaded 1304.1672v2
# Successfully downloaded 1612.01465v3
# Repository 1610.09585v4 already downloaded
# Successfully downloaded 1809.10959v2
# Successfully downloaded 1711.06509v3
# Repository 1805.08318v2 already downloaded
# Successfully downloaded 1804.11332v1
# Repository 1605.03170v3 already downloaded
# Repository 1602.07360v4 already downloaded
# Successfully downloaded 1809.10853v3
# Successfully downloaded 1810.07842v1
# Successfully downloaded 1806.05975v2
# Successfully downloaded 1502.05767v4
# Successfully downloaded 1602.00904v2
# Successfully downloaded 1802.09957v1
# Successfully downloaded 1804.10686v1
# Successfully downloaded 1605.06595v2
# Successfully downloaded 1703.02504v1
# Successfully downloaded 1602.02410v2
# Successfully downloaded 1808.00793v1
# Successfully downloaded 1809.06309v3
# Successfully downloaded 1808.04699v1
# Successfully downloaded 1705.11040v2
# Successfully downloaded 1512.02325v5
# Repository 1701.07875v3 already downloaded
# Successfully downloaded 1703.06103v4
# Successfully downloaded 1901.04095v2
# Successfully downloaded 1708.04439v2
# Successfully downloaded 1411.5928v4
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1812.05692v1
# Successfully downloaded 1809.02058v3
# Successfully downloaded 1810.09305v1
# Successfully downloaded 1809.02196v2
# Successfully downloaded 1804.00497v3
# Successfully downloaded 1805.11365v3
# Repository 1704.00028v3 already downloaded
# Repository 1506.02025v3 already downloaded
# Successfully downloaded 1802.09901v1
# Successfully downloaded 1805.01677v2
# Repository 1405.4053v2 already downloaded
# Successfully downloaded 1707.03692v1
# Repository 1508.06576v2 already downloaded
# Successfully downloaded 1806.02978v1
# Repository 1512.02325v5 already downloaded
# Successfully downloaded 1604.00772v1
# Successfully downloaded 1703.07047v3
# Successfully downloaded 1810.11530v2
# Repository 1505.04597v1 already downloaded
# Repository 1806.02825v1 already downloaded
# Successfully downloaded 1705.03122v3
# Successfully downloaded 1810.11630v1
# Successfully downloaded 1802.03268v2
# Successfully downloaded 1705.09296v2
# Successfully downloaded 1711.08488v2
# Successfully downloaded 1606.01855v1
# Repository 1609.04938v2 already downloaded
# Successfully downloaded 1904.08017v1
# Successfully downloaded 1810.08436v2
# Repository 1508.06576v2 already downloaded
# Successfully downloaded 1606.00931v3
# Repository 1711.09020v3 already downloaded
# Successfully downloaded 1904.06699v2
# Successfully downloaded 1808.06649v1
# Repository 1808.09945v1 already downloaded
# Successfully downloaded 1603.07285v2
# Successfully downloaded 1901.01703v6
# Successfully downloaded 1406.2541v1
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1904.07798v1
# Successfully downloaded 1811.01494v1
# Successfully downloaded 1901.04622v1
# Repository 1707.06347v2 already downloaded
# Repository 1511.00561v3 already downloaded
# Successfully downloaded 1612.01051v4
# Successfully downloaded 1902.01069v2
# Successfully downloaded 1902.06522v1
# Successfully downloaded 1606.00704v3
# Successfully downloaded 1801.04871v1
# Successfully downloaded 1802.06182v1
# Successfully downloaded 1804.02767v1
# Repository 1503.08895v5 already downloaded
# Successfully downloaded 1803.08240v1
# Successfully downloaded 1806.02169v2
# Successfully downloaded 1804.09170v4
# Successfully downloaded 1203.1005v3
# Successfully downloaded 1702.01587v1
# Successfully downloaded 1804.07177v1
# Successfully downloaded 1810.11261v1
# Repository 1506.02640v5 already downloaded
# Successfully downloaded 1806.05780v4
# Successfully downloaded 1802.05365v2
# Successfully downloaded 1805.09662v2
# Successfully downloaded 1805.11080v1
# Repository 1703.10593v6 already downloaded
# Successfully downloaded 1806.09055v2
# Could not download 1711.06798v3 due to a network error
# Repository 1506.02640v5 already downloaded
# Successfully downloaded 1708.02596v2
# Successfully downloaded 1606.03657v1
# Successfully downloaded 1502.03044v3
# Successfully downloaded 1411.1784v1
# Repository 1406.2661v1 already downloaded
# Successfully downloaded 1807.02654v1
# Repository 1607.06349v1 already downloaded
# Successfully downloaded 1601.04589v1
# Successfully downloaded 1709.08041v1
# Repository 1703.08710v2 already downloaded
# Successfully downloaded 1608.04471v3
# Successfully downloaded 1811.06186v4
# Successfully downloaded 1803.10615v2
# Successfully downloaded 1804.07656v1
# Repository 1506.02640v5 already downloaded
# Successfully downloaded 1705.00347v2
# Successfully downloaded 1904.09658v4
# Repository 1705.09759v1 already downloaded
# Successfully downloaded 1807.09010v3
# Repository 1411.4038v2 already downloaded
# Successfully downloaded 1802.10419v3
# Successfully downloaded 1704.04347v3
# Successfully downloaded 1606.05250v3
# Successfully downloaded 1809.04281v3
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1507.08240v3
# Repository 1411.1784v1 already downloaded
# Successfully downloaded 1602.00134v4
# Repository 1606.03657v1 already downloaded
# Successfully downloaded 1805.06431v2
# Successfully downloaded 1707.08081v2
# Successfully downloaded 1806.07239v1
# Successfully downloaded 1806.01794v2
# Successfully downloaded 1808.03737v2
# Repository 1707.06347v2 already downloaded
# Successfully downloaded 1904.09380v1
# Successfully downloaded 1709.04326v4
# Successfully downloaded 1603.09095v6
# Repository 1809.02627v1 already downloaded
# Successfully downloaded 1810.08854v2
# Successfully downloaded 1701.09042v1
# Repository 1806.09055v2 already downloaded
# Successfully downloaded 1810.00361v1
# Successfully downloaded 1802.05098v3
# Successfully downloaded 1504.00325v2
# Successfully downloaded 1807.03527v1
# Successfully downloaded 1611.09913v3
# Successfully downloaded 1806.08756v2
# Successfully downloaded 1711.00123v3
# Successfully downloaded 1712.09665v2
# Repository 1512.03385v1 already downloaded
# Successfully downloaded 1904.09675v2
# Successfully downloaded 1709.07902v1
# Successfully downloaded 1703.10908v4
# Successfully downloaded 1606.05908v2
# Successfully downloaded 1709.01447v1
# Successfully downloaded 1804.06812v1
# Successfully downloaded 1902.10547v3
# Successfully downloaded 1512.01100v2
# Repository 1704.04861v1 already downloaded
# Successfully downloaded 1910.07467v1
# Successfully downloaded 1910.07475v2
# Successfully downloaded 1706.09856v1
# Successfully downloaded 1709.03199v2
# Successfully downloaded 1708.02139v1
# Successfully downloaded 1508.04025v5
# Repository 1409.0473v7 already downloaded
# Successfully downloaded 1810.11981v3
# Repository 1801.04871v1 already downloaded
# Successfully downloaded 1902.00751v2
# Successfully downloaded 1511.01432v1
# Successfully downloaded 1811.12150v1
# Repository 1709.07492v2 already downloaded
# Repository 1606.00373v2 already downloaded
# Successfully downloaded 1805.08095v1
# Successfully downloaded 1812.00151v2
# Repository 1611.01603v6 already downloaded
# Successfully downloaded 1806.00720v1
# Successfully downloaded 1904.03751
# Repository 1602.07776v4 already downloaded
# Successfully downloaded 1603.02754v3
# Successfully downloaded 1806.04731v3
# Repository 1810.04805v2 already downloaded
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1902.10904v2
# Successfully downloaded 1612.00222v1
# Repository 1804.02767v1 already downloaded
# Repository 1705.03122v3 already downloaded
# Successfully downloaded 1811.00293v2
# Successfully downloaded 1802.08219v3
# Successfully downloaded 1711.05144v5
# Successfully downloaded 1703.06284v2
# Successfully downloaded 1804.05830v1
# Successfully downloaded 1711.08848v5
# Successfully downloaded 1801.07175v2
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1706.05098v1
# Successfully downloaded 1812.04808v1
# Successfully downloaded 1606.00189v1
# Successfully downloaded 1703.04782v3
# Successfully downloaded 1704.08424v2
# Successfully downloaded 1806.01261v3
# Successfully downloaded 1702.08139v2
# Successfully downloaded 1904.03371v1
# Successfully downloaded 1611.07567v1
# Successfully downloaded 1702.01460v5
# Repository 1705.05065v2 already downloaded
# Successfully downloaded 1609.08675v1
# Repository 1611.07004v3 already downloaded
# Repository 1406.2661v1 already downloaded
# Successfully downloaded 1703.01365v2
# Successfully downloaded 1809.00252v2
# Repository 1810.04805v2 already downloaded
# Repository 1508.07909v5 already downloaded
# Successfully downloaded 1805.09019v1
# Repository 1608.04471v3 already downloaded
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1802.05695v2
# Repository 1512.02325v5 already downloaded
# Repository 1608.06993v5 already downloaded
# Repository 1409.1556v6 already downloaded
# Successfully downloaded 1810.07225v1
# Successfully downloaded 1711.00199v3
# Successfully downloaded 1703.07511v3
# Successfully downloaded 1807.10076v3
# Successfully downloaded 1610.02391v3
# Successfully downloaded 1801.02203v1
# Successfully downloaded 1703.09554v5
# Repository 1602.07360v4 already downloaded
# Successfully downloaded 1908.11587v1
# Successfully downloaded 1903.06708v2
# Successfully downloaded 1805.10255v1
# Successfully downloaded 1811.08305v1
# Successfully downloaded 1603.01354v5
# Successfully downloaded 1704.03477v4
# Successfully downloaded 1904.07475v4
# Successfully downloaded 1712.08290v2
# Successfully downloaded 1708.04782v1
# Successfully downloaded 1512.04150v1
# Repository 1408.5882v2 already downloaded
# Successfully downloaded 1703.03329v2
# Successfully downloaded 1902.05625v2
# Successfully downloaded 1510.07493v1
# Successfully downloaded 1702.03044v2
# Successfully downloaded 1706.04638v3
# Successfully downloaded 1706.05137v1
# Successfully downloaded 1807.03819v3
# Successfully downloaded 1807.00775v1
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1802.07606v1
# Successfully downloaded 1511.05879v2
# Successfully downloaded 1805.02523v3
# Successfully downloaded 1806.01743v2
# Successfully downloaded 1809.04766v2
# Successfully downloaded 1811.02545v1
# Successfully downloaded 1704.02422v2
# Repository 1711.09151v1 already downloaded
# Successfully downloaded 1709.08292v1
# Successfully downloaded 1708.00805v1
# Successfully downloaded 1701.04520v1
# Repository 1804.08450v1 already downloaded
# Successfully downloaded 1810.00236v2
# Successfully downloaded 1809.04430v1
# Successfully downloaded 1810.04793v3
# Successfully downloaded 1710.11342v2
# Successfully downloaded 1902.07816v2
# Successfully downloaded 1804.09325v6
# Successfully downloaded 1512.00250v3
# Successfully downloaded 1511.07763v2
# Successfully downloaded 1809.00786v2
# Successfully downloaded 1806.07380v1
# Successfully downloaded 1705.07206v2
# Successfully downloaded 1611.02185v5
# Successfully downloaded 1906.07155v1
# Successfully downloaded 1612.03268v1
# Successfully downloaded 1806.05437v2
# Successfully downloaded 1812.02713v1
# Successfully downloaded 1711.08792v1
# Successfully downloaded 1509.05209v1
# Successfully downloaded 1503.02330v1
# Successfully downloaded 1612.01064v3
# Successfully downloaded 1512.02406v3
# Successfully downloaded 1711.10378v2
# Successfully downloaded 1406.1078v3
# Successfully downloaded 1712.07557v2
# Successfully downloaded 1705.10467v2
# Successfully downloaded 1709.02508v1
# Successfully downloaded 1712.06924v5
# Successfully downloaded 1812.00531v1
# Repository 1707.07998v3 already downloaded
# Successfully downloaded 1606.00776v2
# Successfully downloaded 1605.03481v2
# Successfully downloaded 1205.2618v1
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1706.07522v1
# Successfully downloaded 1707.02275v1
# Successfully downloaded 1804.06872v3
# Successfully downloaded 1703.04357v1
# Successfully downloaded 1703.11000v2
# Repository 1803.03816v2 already downloaded
# Successfully downloaded 1612.05729v1
# Successfully downloaded 1805.03989v2
# Successfully downloaded 1706.09569v2
# Successfully downloaded 1803.11125v1
# Successfully downloaded 1610.04823v4
# Repository 1506.06256v1 already downloaded
# Successfully downloaded 1806.02559v1
# Successfully downloaded 1810.09945v2
# Repository 1507.05717v1 already downloaded
# Successfully downloaded 1901.00392v1
# Successfully downloaded 1512.08849v2
# Successfully downloaded 1804.04888v2
# Successfully downloaded 1903.12473v2
# Successfully downloaded 1902.02593v3
# Repository 1301.3781v3 already downloaded
# Repository 1703.03130v1 already downloaded
# Repository 1511.02889v1 already downloaded
# Repository 1711.08488v2 already downloaded
# Successfully downloaded 1805.11921v3
# Successfully downloaded 1701.06649v1
# Successfully downloaded 1805.07932v2
# Successfully downloaded 1511.05493v4
# Successfully downloaded 1511.02274v2
# Successfully downloaded 1805.12244v4
# Repository 1805.10255v1 already downloaded
# Repository 1708.02002v2 already downloaded
# Successfully downloaded 1711.08336v2
# Successfully downloaded 1501.03227v3
# Repository 1703.05175v2 already downloaded
# Repository 1704.04224v1 already downloaded
# Repository 1612.03144v2 already downloaded
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1609.03677v3
# Repository 1712.01815v1 already downloaded
# Repository 1506.01497v3 already downloaded
# Repository 1505.04597v1 already downloaded
# Repository 1702.02138v2 already downloaded
# Successfully downloaded 1705.05363v1
# Successfully downloaded 1411.6970v2
# Repository 1503.03832v3 already downloaded
# Successfully downloaded 1706.10059v2
# Successfully downloaded 1710.10814v1
# Successfully downloaded 1808.06601v2
# Repository 1506.06256v1 already downloaded
# Successfully downloaded 1608.03983v5
# Successfully downloaded 1607.08822v1
# Successfully downloaded 1712.08726v2
# Repository 1703.03130v1 already downloaded
# Successfully downloaded 1612.01887v2
# Successfully downloaded 1511.06422v7
# Successfully downloaded 1809.06839v1
# Successfully downloaded 1901.08334v1
# Successfully downloaded 1811.11430v1
# Successfully downloaded 1604.01325v2
# Repository 1506.01497v3 already downloaded
# Successfully downloaded 1704.01745v1
# Repository 1702.02138v2 already downloaded
# Successfully downloaded 1812.11948v1
# Successfully downloaded 1802.10254v2
# Successfully downloaded 1903.05196v2
# Successfully downloaded 1805.11565v4
# Repository 1612.03144v2 already downloaded
# Repository 1512.04150v1 already downloaded
# Successfully downloaded 1802.05667v2
# Successfully downloaded 1811.12758v2
# Successfully downloaded 1807.09097v1
# Successfully downloaded 1206.2248v6
# Repository 1711.05225v3 already downloaded
# Successfully downloaded 1807.08312v1
# Successfully downloaded 1808.00723v1
# Repository 1712.01815v1 already downloaded
# Successfully downloaded 1902.03477v2
# Successfully downloaded 1606.04080v2
# Successfully downloaded 1807.03748v2
# Successfully downloaded 1904.03450v1
# Successfully downloaded 1904.05647v1
# Successfully downloaded 1811.09361v4
# Successfully downloaded 1703.10135v2
# Successfully downloaded 1712.00796v3
# Successfully downloaded 1802.01569v2
# Successfully downloaded 1602.04105v3
# Repository 1801.06146v5 already downloaded
# Successfully downloaded 1711.10925v3
# Repository 1405.4053v2 already downloaded
# Successfully downloaded 1811.04210v2
# Successfully downloaded 1802.06474v5
# Successfully downloaded 1604.05000v3
# Successfully downloaded 1705.09479v2
# Successfully downloaded 1710.01330v4
# Successfully downloaded 1802.07814v2
# Successfully downloaded 1709.05283v1
# Repository 1304.1672v2 already downloaded
# Successfully downloaded 1804.08847v1
# Repository 1304.1672v2 already downloaded
# Successfully downloaded 1803.05449v1
# Successfully downloaded 1806.11146v2
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1804.00079v1
# Successfully downloaded 1711.02281v2
# Successfully downloaded 1902.04704v2
# Successfully downloaded 1611.05431v2
# Repository 1703.07737v4 already downloaded
# Successfully downloaded 1902.03368v2
# Successfully downloaded 1811.05181v1
# Successfully downloaded 1511.04143v4
# Successfully downloaded 1911.07246v1
# Repository 1702.08835v3 already downloaded
# Successfully downloaded 1609.03683v2
# Successfully downloaded 1505.03540v3
# Successfully downloaded 1901.06803v1
# Repository 1712.01815v1 already downloaded
# Successfully downloaded 1804.06500v2
# Repository 1708.04782v1 already downloaded
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1810.05739v4
# Successfully downloaded 1803.08495v1
# Repository 1705.02364v5 already downloaded
# Successfully downloaded 1803.07950v2
# Successfully downloaded 1802.05027v2
# Successfully downloaded 1901.10860v2
# Successfully downloaded 1812.10382v1
# Repository 1605.03170v3 already downloaded
# Successfully downloaded 1407.6245v1
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1810.08379v1
# Successfully downloaded 1612.03769v1
# Successfully downloaded 1806.06553v1
# Repository 1612.03144v2 already downloaded
# Successfully downloaded 1504.06852v2
# Successfully downloaded 1808.03912v1
# Successfully downloaded 1712.07581v2
# Successfully downloaded 1609.07540v1
# Successfully downloaded 1902.06007v2
# Successfully downloaded 1710.11063v3
# Successfully downloaded 1803.10122v4
# Successfully downloaded 1710.09289v4
# Successfully downloaded 1812.01353v5
# Successfully downloaded 1610.06449v1
# Repository 1605.09782v7 already downloaded
# Successfully downloaded 1803.02291v3
# Successfully downloaded 1612.07837v2
# Successfully downloaded 1610.00465v1
# Repository 1603.01417v1 already downloaded
# Successfully downloaded 1611.08387v1
# Successfully downloaded 1707.03333v1
# Successfully downloaded 1703.05884v2
# Successfully downloaded 1808.10692v1
# Successfully downloaded 1705.08623v2
# Successfully downloaded 1808.05469v2
# Repository 1403.6652v2 already downloaded
# Repository 1602.07360v4 already downloaded
# Successfully downloaded 1707.02392v3
# Successfully downloaded 1802.10250v3
# Successfully downloaded 1710.10951v2
# Repository 1805.03359v2 already downloaded
# Successfully downloaded 1706.04957v2
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1805.07549v1
# Successfully downloaded 1801.00062v1
# Repository 1412.7753v2 already downloaded
# Successfully downloaded 1807.02125v2
# Repository 1901.03353v1 already downloaded
# Successfully downloaded 1801.00926v3
# Successfully downloaded 1810.05475v1
# Successfully downloaded 1712.01076v1
# Repository 1604.08610v2 already downloaded
# Successfully downloaded 1807.02128v4
# Successfully downloaded 1806.03589v2
# Successfully downloaded 1806.07119v7
# Repository 1810.04805v2 already downloaded
# Repository 1612.00593v2 already downloaded
# Repository 1703.06870v3 already downloaded
# Repository 1408.5882v2 already downloaded
# Successfully downloaded 1708.04552v2
# Successfully downloaded 1806.02199v7
# Successfully downloaded 1805.12402v1
# Successfully downloaded 1605.06197v3
# Successfully downloaded 1712.01034v2
# Repository 1802.05365v2 already downloaded
# Successfully downloaded 1812.09587v2
# Repository 1609.03677v3 already downloaded
# Repository 1703.07469v1 already downloaded
# Successfully downloaded 1503.07283v1
# Repository 1703.06211v3 already downloaded
# Successfully downloaded 1206.6471v1
# Successfully downloaded 1709.00103v7
# Successfully downloaded 1807.03052v1
# Successfully downloaded 1712.05382v2
# Successfully downloaded 1702.04457v2
# Repository 1807.03819v3 already downloaded
# Successfully downloaded 1610.09756v2
# Successfully downloaded 1706.00388v2
# Successfully downloaded 1704.03732v4
# Successfully downloaded 1506.01186v6
# Repository 1808.00508v1 already downloaded
# Repository 1512.03385v1 already downloaded
# Repository 1609.04309v3 already downloaded
# Successfully downloaded 1507.06217v3
# Successfully downloaded 1710.05476v3
# Successfully downloaded 1704.05958v2
# Successfully downloaded 1410.3916v11
# Successfully downloaded 1705.07831v2
# Successfully downloaded 1804.02755v2
# Successfully downloaded 1603.00788v1
# Successfully downloaded 1602.00177v1
# Successfully downloaded 1605.04603v1
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1401.0942v2
# Successfully downloaded 1505.04366v1
# Successfully downloaded 1603.04992v2
# Successfully downloaded 1703.10717v4
# Successfully downloaded 1710.05381v2
# Successfully downloaded 1506.07285v5
# Successfully downloaded 1612.01452v2
# Repository 1508.06576v2 already downloaded
# Successfully downloaded 1801.10247v1
# Successfully downloaded 1707.06799v2
# Successfully downloaded 1704.01748v3
# Successfully downloaded 1802.05384v3
# Successfully downloaded 1805.07684v2
# Successfully downloaded 1803.10161v4
# Successfully downloaded 1805.07848v2
# Successfully downloaded 1511.04119v3
# Successfully downloaded 1502.05577v2
# Successfully downloaded 1812.01115v2
# Successfully downloaded 1809.03992v1
# Repository 1612.00593v2 already downloaded
# Repository 1609.04938v2 already downloaded
# Repository 1612.01051v4 already downloaded
# Repository 1410.3916v11 already downloaded
# Successfully downloaded 1802.08797v2
# Repository 1312.6114v10 already downloaded
# Successfully downloaded 1801.07892v2
# Repository 1806.03589v2 already downloaded
# Successfully downloaded 1804.11146v1
# Successfully downloaded 1606.02960v2
# Successfully downloaded 1503.01954v2
# Repository 1506.02640v5 already downloaded
# Successfully downloaded 1606.08866v1
# Successfully downloaded 1607.03055v1
# Successfully downloaded 1606.02891v2
# Repository 1312.6114v10 already downloaded
# Successfully downloaded 1807.09995v1
# Successfully downloaded 1711.07433v1
# Successfully downloaded 1803.08024v2
# Successfully downloaded 1805.07909v1
# Successfully downloaded 1711.08477v2
# Successfully downloaded 1707.05425v6
# Successfully downloaded 1711.03638v2
# Successfully downloaded 1901.03136v2
# Successfully downloaded 1610.08763v2
# Successfully downloaded 1707.07128v1
# Successfully downloaded 1808.00529v1
# Successfully downloaded 1507.01784v2
# Successfully downloaded 1805.10939v3
# Repository 1312.4400v3 already downloaded
# Successfully downloaded 1511.02916v1
# Successfully downloaded 1801.10198v1
# Successfully downloaded 1505.00110v1
# Successfully downloaded 1706.05587v3
# Repository 1409.1556v6 already downloaded
# Successfully downloaded 1706.02633v2
# Successfully downloaded 1705.04608v2
# Repository 1409.0473v7 already downloaded
# Repository 1806.09055v2 already downloaded
# Successfully downloaded 1801.01999v1
# Successfully downloaded 1804.09502v1
# Successfully downloaded 1705.10461v3
# Successfully downloaded 1812.10860v5
# Repository 1411.4038v2 already downloaded
# Successfully downloaded 1901.04846v3
# Repository 1512.03385v1 already downloaded
# Successfully downloaded 1903.10683v3
# Successfully downloaded 1911.08718v2
# Successfully downloaded 1806.05376v1
# Successfully downloaded 1809.06858v1
# Repository 1509.02971v6 already downloaded
# Successfully downloaded 1708.06453v2
# Successfully downloaded 1809.05525v2
# Successfully downloaded 1712.08207v3
# Successfully downloaded 1907.12415v2
# Successfully downloaded 1712.07240v1
# Successfully downloaded 1611.01547v5
# Repository 1804.02767v1 already downloaded
# Successfully downloaded 1607.06025v2
# Successfully downloaded 1811.00416v2
# Repository 1609.05158v2 already downloaded
# Successfully downloaded 1305.4537v5
# Successfully downloaded 1503.05671v6
# Successfully downloaded 1708.09427v5
# Repository 1308.0850v5 already downloaded
# Successfully downloaded 1704.06904v1
# Repository 1702.03814v3 already downloaded
# Successfully downloaded 1708.04133v1
# Successfully downloaded 1704.04664v2
# Repository 1610.02357v3 already downloaded
# Successfully downloaded 1310.1531v1
# Successfully downloaded 1811.12043v1
# Repository 1609.04802v5 already downloaded
# Repository 1312.5602v1 already downloaded
# Repository 1810.04805v2 already downloaded
# Repository 1504.00325v2 already downloaded
# Successfully downloaded 1807.09936v1
# Repository 1707.06347v2 already downloaded
# Successfully downloaded 1812.10650v1
# Successfully downloaded 1807.09190v2
# Repository 1707.05425v6 already downloaded
# Repository 1511.01432v1 already downloaded
# Successfully downloaded 1608.00220v1
# Repository 1703.06870v3 already downloaded
# Successfully downloaded 1712.00559v3
# Successfully downloaded 1506.02142v6
# Repository 1704.04224v1 already downloaded
# Successfully downloaded 1306.1031v3
# Successfully downloaded 1712.00080v2
# Successfully downloaded 1710.08092v2
# Repository 1804.07573v4 already downloaded
# Repository 1612.03651v1 already downloaded
# Successfully downloaded 1804.07899v2
# Repository 1705.03122v3 already downloaded
# Successfully downloaded 1803.05036v1
# Successfully downloaded 1803.01500v2
# Successfully downloaded 1608.06043v3
# Repository 1612.08242v1 already downloaded
# Successfully downloaded 1810.04250v2
# Successfully downloaded 1810.02525v1
# Successfully downloaded 1805.11462v1
# Successfully downloaded 1610.02424v2
# Successfully downloaded 1704.03956v2
# Successfully downloaded 1810.12894v1
# Successfully downloaded 1705.06368v3
# Repository 1609.04802v5 already downloaded
# Successfully downloaded 1910.06489v3
# Successfully downloaded 1803.02893v1
# Successfully downloaded 1810.02555v2
# Successfully downloaded 1812.08915v1
# Successfully downloaded 1806.07066v1
# Successfully downloaded 1708.06008v2
# Successfully downloaded 0908.4425v1
# Repository 1511.06581v3 already downloaded
# Successfully downloaded 1901.02532v1
# Successfully downloaded 1910.07210v2
# Successfully downloaded 1705.02009v1
# Repository 1409.1556v6 already downloaded
# Repository 1608.06043v3 already downloaded
# Repository 1412.1820v2 already downloaded
# Repository 1408.5882v2 already downloaded
# Successfully downloaded 1804.00308v1
# Successfully downloaded 1910.01592v1
# Successfully downloaded 1602.07261v2
# Successfully downloaded 1410.7326v3
# Successfully downloaded 1411.3159v2
# Repository 1511.01432v1 already downloaded
# Successfully downloaded 1810.00774v1
# Successfully downloaded 1610.08735v2
# Repository 1809.02627v1 already downloaded
# Successfully downloaded 1610.10087v1
# Successfully downloaded 1607.02488v2
# Repository 1702.02138v2 already downloaded
# Successfully downloaded 1701.05363v3
# Successfully downloaded 1901.00158v2
# Successfully downloaded 1506.04834v3
# Successfully downloaded 1902.03155v1
# Successfully downloaded 1803.03178v1
# Successfully downloaded 1906.01083v1
# Successfully downloaded 1806.06457v2
# Repository 1605.00316v1 already downloaded
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1809.04206v3
# Successfully downloaded 1712.01521v1
# Repository 1706.03762v5 already downloaded
# Repository 1706.03762v5 already downloaded
# Successfully downloaded 1702.02447v2
# Repository 1607.04606v2 already downloaded
# Successfully downloaded 1909.05289v2
# Successfully downloaded 1904.09925v4
# Successfully downloaded 1904.03441v1
# Successfully downloaded 1712.02136v3
# Successfully downloaded 1908.10828v1
# Successfully downloaded 1908.11046v2
# Successfully downloaded 1810.02716v1
# Successfully downloaded 1702.08423v2
# Repository 1706.01427v1 already downloaded
# Repository 1810.04805v2 already downloaded
# Repository 1711.08488v2 already downloaded
# Successfully downloaded 1811.11662v1
# Repository 1607.04606v2 already downloaded
# Successfully downloaded 1603.01547v2
# Successfully downloaded 1803.07416v1
# Successfully downloaded 1503.05543v1
# Successfully downloaded 1806.05357v1
# Successfully downloaded 1704.02665v3
# Successfully downloaded 1902.03228v1
# Successfully downloaded 1608.06651v2
# Successfully downloaded 1811.08011v1
# Successfully downloaded 1803.08137v1
# Successfully downloaded 1710.03958v2
# Successfully downloaded 1801.02209v2
# Successfully downloaded 1707.01164v2
# Repository 1810.04805v2 already downloaded
# Repository 1511.01432v1 already downloaded
# Repository 1409.0473v7 already downloaded
# Repository 1401.0942v2 already downloaded
# Repository 1704.00051v2 already downloaded
# Successfully downloaded 1612.09212v1
# Successfully downloaded 1810.06936v2
# Successfully downloaded 1604.04494v2
# Repository 1603.01360v3 already downloaded
# Successfully downloaded 1704.06960v5
# Successfully downloaded 1710.01789v1
# Successfully downloaded 1812.01936v1
# Successfully downloaded 1611.01799v1
# Successfully downloaded 1611.09969v2
# Successfully downloaded 1704.08908v2
# Successfully downloaded 1702.00167v2
# Successfully downloaded 1809.01407v2
# Could not download 1812.04948v3 due to a network error
# Successfully downloaded 1704.03162v2
# Repository 1806.06923v1 already downloaded
# Successfully downloaded 1412.6572v3
# Successfully downloaded 1805.07036v1
# Successfully downloaded 1901.02244v1
# Successfully downloaded 1610.03017v3
# Successfully downloaded 1810.02541v7
# Successfully downloaded 1904.03345v2
# Successfully downloaded 1801.05134v1
# Successfully downloaded 1807.07024v2
# Successfully downloaded 1609.01064v2
# Repository 1312.6114v10 already downloaded
# Repository 1810.04805v2 already downloaded
# Successfully downloaded 1811.07782v1
# Successfully downloaded 1809.00999v3
# Successfully downloaded 1808.08745v1
# Repository 1706.03762v5 already downloaded
# Repository 1505.04597v1 already downloaded
# Successfully downloaded 1606.04797v1
# Repository 1712.01815v1 already downloaded
# Repository 1604.07316v1 already downloaded
# Repository 1304.1672v2 already downloaded
# Successfully downloaded 1610.05949v2
# Successfully downloaded 1707.04615v1
# Successfully downloaded 1804.08992v4
# Successfully downloaded 1807.02011v3
